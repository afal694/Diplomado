# %%
import pandas as pd

# %%
data = pd.read_csv("MOCK_DATA.csv")

# %%
display(data)
# Out:
#      id first_name last_name                       email       gender  \
# 0     1        Edy    Connop           econnop0@dell.com       Female
# 1     2     Sisely   Creamer         screamer1@chron.com       Female
# 2     3     Anders  Houdmont  ahoudmont2@squarespace.com  Genderqueer
# 3     4       Reed   Frensch     rfrensch3@quantcast.com         Male
# 4     5  Maighdiln     Doman            mdoman4@army.mil       Female
# ..  ...        ...       ...                         ...          ...
# 95   96     Gizela  Caulkett       gcaulkett2n@salon.com       Female
# 96   97    Madison   Zottoli   mzottoli2o@shutterfly.com         Male
# 97   98      Timmy   Swayton        tswayton2p@intel.com  Genderfluid
# 98   99    Kirstin   Anshell         kanshell2q@hibu.com  Genderqueer
# 99  100      Glori  O'Sharry        gosharry2r@wikia.com       Female
#
#          ip_address
# 0      2.243.234.31
# 1      39.4.129.205
# 2   150.182.254.218
# 3   225.234.110.188
# ...

# %%
data.head(10)
# Out:
#    id first_name   last_name                       email       gender  \
# 0   1        Edy      Connop           econnop0@dell.com       Female
# 1   2     Sisely     Creamer         screamer1@chron.com       Female
# 2   3     Anders    Houdmont  ahoudmont2@squarespace.com  Genderqueer
# 3   4       Reed     Frensch     rfrensch3@quantcast.com         Male
# 4   5  Maighdiln       Doman            mdoman4@army.mil       Female
# 5   6       Nata       Deppe   ndeppe5@howstuffworks.com       Female
# 6   7       Nell  Twelvetree   ntwelvetree6@edublogs.org       Female
# 7   8  Hildagard    Pounsett        hpounsett7@slate.com       Female
# 8   9      Mayer  Clapperton       mclapperton8@1688.com         Male
# 9  10   Barbabra      Osmond          bosmond9@globo.com       Female
#
#         ip_address
# 0     2.243.234.31
# 1     39.4.129.205
# 2  150.182.254.218
# 3  225.234.110.188
# 4  246.207.142.174
# 5    104.33.218.14
# 6    229.85.154.70
# 7        30.9.7.29
# ...

# %%
data.tail()
# Out:
#      id first_name last_name                      email       gender  \
# 95   96     Gizela  Caulkett      gcaulkett2n@salon.com       Female
# 96   97    Madison   Zottoli  mzottoli2o@shutterfly.com         Male
# 97   98      Timmy   Swayton       tswayton2p@intel.com  Genderfluid
# 98   99    Kirstin   Anshell        kanshell2q@hibu.com  Genderqueer
# 99  100      Glori  O'Sharry       gosharry2r@wikia.com       Female
#
#          ip_address
# 95    32.80.235.119
# 96  122.243.185.216
# 97  213.134.158.252
# 98   188.145.165.41
# 99     182.23.9.121

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          100 non-null    int64
#  1   first_name  100 non-null    object
#  2   last_name   100 non-null    object
#  3   email       100 non-null    object
#  4   gender      100 non-null    object
#  5   ip_address  100 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 4.8+ KB

# %%
print("La forma de la base de datos es: ", data.shape)
# Out:
# La forma de la base de datos es:  (100, 6)

# %%
print("tipo de objeto en cada columna", data.dtypes)
# Out:
# tipo de objeto en cada columna id             int64
# first_name    object
# last_name     object
# email         object
# gender        object
# ip_address    object
# dtype: object

# %%
data.describe(include="all")
# Out:
#                 id first_name last_name              email  gender  \
# count   100.000000        100       100                100     100
# unique         NaN        100       100                100       7
# top            NaN        Edy    Connop  econnop0@dell.com  Female
# freq           NaN          1         1                  1      48
# mean     50.500000        NaN       NaN                NaN     NaN
# std      29.011492        NaN       NaN                NaN     NaN
# min       1.000000        NaN       NaN                NaN     NaN
# 25%      25.750000        NaN       NaN                NaN     NaN
# 50%      50.500000        NaN       NaN                NaN     NaN
# 75%      75.250000        NaN       NaN                NaN     NaN
# max     100.000000        NaN       NaN                NaN     NaN
#
#           ip_address
# count            100
# unique           100
# top     2.243.234.31
# freq               1
# mean             NaN
# std              NaN
# ...

# %% [markdown]
# ### Seleccionar subconjuntos de una base de datos

# %%
data.columns
# Out:
# Index(['id', 'first_name', 'last_name', 'email', 'gender', 'ip_address'], dtype='object')

# %%
first_names = data["first_name"]

# %%
print(first_names)
# Out:
# 0           Edy
# 1        Sisely
# 2        Anders
# 3          Reed
# 4     Maighdiln
#         ...
# 95       Gizela
# 96      Madison
# 97        Timmy
# 98      Kirstin
# 99        Glori
# Name: first_name, Length: 100, dtype: object

# %%
print(first_names.shape, type(first_names))
# Out:
# (100,) <class 'pandas.core.series.Series'>

# %%
name_email = data[["first_name", "last_name", "email"]]
name_email
# Out:
#    first_name last_name                       email
# 0         Edy    Connop           econnop0@dell.com
# 1      Sisely   Creamer         screamer1@chron.com
# 2      Anders  Houdmont  ahoudmont2@squarespace.com
# 3        Reed   Frensch     rfrensch3@quantcast.com
# 4   Maighdiln     Doman            mdoman4@army.mil
# ..        ...       ...                         ...
# 95     Gizela  Caulkett       gcaulkett2n@salon.com
# 96    Madison   Zottoli   mzottoli2o@shutterfly.com
# 97      Timmy   Swayton        tswayton2p@intel.com
# 98    Kirstin   Anshell         kanshell2q@hibu.com
# 99      Glori  O'Sharry        gosharry2r@wikia.com
#
# [100 rows x 3 columns]

# %% [markdown]
# ### Escoger filas

# %%
# iloc

display(data.iloc[[1,5,55,13]])
# Out:
#     id first_name last_name                      email       gender  \
# 1    2     Sisely   Creamer        screamer1@chron.com       Female
# 5    6       Nata     Deppe  ndeppe5@howstuffworks.com       Female
# 55  56      Cobby   Cadlock   ccadlock1j@economist.com   Polygender
# 13  14    Jeramey  Akeherst        jakeherstd@ucoz.com  Genderfluid
#
#        ip_address
# 1    39.4.129.205
# 5   104.33.218.14
# 55  63.176.100.20
# 13  212.113.14.22

# %%
display(data.iloc[67:79])
# Out:
#     id first_name   last_name                        email       gender  \
# 67  68     Rickey        Ziem             rziem1v@noaa.gov         Male
# 68  69        Boy     Couzens       bcouzens1w@spotify.com         Male
# 69  70   Chloette    Leinster    cleinster1x@wordpress.com       Female
# 70  71     Ricard      Kemmet        rkemmet1y@spotify.com         Male
# 71  72      Rhody     Schwier         rschwier1z@amazon.de       Female
# 72  73   Antonina      Gawkes           agawkes20@etsy.com       Female
# 73  74        Con  Bartolacci  cbartolacci21@people.com.cn         Male
# 74  75   Vittorio    Frankham       vfrankham22@netlog.com  Genderqueer
# 75  76   Cariotta      Prando      cprando23@wikipedia.org       Female
# 76  77     Brnaby     Shermar         bshermar24@baidu.com         Male
# 77  78   Vladamir      Oxbrow    voxbrow25@sourceforge.net         Male
# 78  79       Reta      Moline         rmoline26@google.com       Female
#
#         ip_address
# ...

# %%
display(data.iloc[0:5,[1,2,5]])
# Out:
#   first_name last_name       ip_address
# 0        Edy    Connop     2.243.234.31
# 1     Sisely   Creamer     39.4.129.205
# 2     Anders  Houdmont  150.182.254.218
# 3       Reed   Frensch  225.234.110.188
# 4  Maighdiln     Doman  246.207.142.174

# %%
data["ip_address"]
# Out:
# 0        2.243.234.31
# 1        39.4.129.205
# 2     150.182.254.218
# 3     225.234.110.188
# 4     246.207.142.174
#            ...
# 95      32.80.235.119
# 96    122.243.185.216
# 97    213.134.158.252
# 98     188.145.165.41
# 99       182.23.9.121
# Name: ip_address, Length: 100, dtype: object

# %%
data["gender"] == "Female"
# Out:
# 0      True
# 1      True
# 2     False
# 3     False
# 4      True
#       ...
# 95     True
# 96    False
# 97    False
# 98    False
# 99     True
# Name: gender, Length: 100, dtype: bool

# %%
women = data[data["gender"] == "Female"].iloc[:,[1,2,3,5]]
display(women.tail())
# Out:
#     first_name last_name                        email      ip_address
# 90  Margarette    Kilban          mkilban2i@wikia.com  124.131.190.89
# 91   Benedetta    Stitch  bstitch2j@blogtalkradio.com   34.226.224.28
# 92      Karola    Sipson        ksipson2k@yahoo.co.jp  91.112.155.205
# 95      Gizela  Caulkett        gcaulkett2n@salon.com   32.80.235.119
# 99       Glori  O'Sharry         gosharry2r@wikia.com    182.23.9.121
